# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://www.flipkart.com/')

# %%
try:
    login_X_button = driver.find_element_by_xpath('//button[@class="_2KpZ6l _2doB4z"]')                      # Button to close login popup
    login_X_button.click()
except NoSuchElementException :
     print("No Login page")

# %%
driver.find_element_by_xpath("//input[@class='_3704LK']").send_keys('pixel')
driver .find_element_by_xpath("//button[@class='L0Z3Pu']").click()

# %%
Product_URL = []
for url in driver.find_elements_by_xpath('//a[@class="_1fQZEK"]'):
    Product_URL.append(url.get_attribute("href"))
Product_URL
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-355fe42e67cc> in <module>
#       1 Product_URL = []
# ----> 2 for url in driver.find_elements_by_xpath('//a[@class="_1fQZEK"]//a'):
#       3     Product_URL.append(url.get_attribute("href"))
#       4 Product_URL
#
# NameError: name 'driver' is not defined

# %%
len(Product_URL)
# Out:
# 24

# %%
RAM=[]
Name=[]
Price=[]
Colour=[]
Model_name=[]
Processor=[]
Storage_ROM=[]
Battery_Type=[]
Processor_Cores=[]
Primary_Camera=[]
Battery_Capacity=[]
Secondary_Camera=[]
Primary_Camera=[]
Display_Resolution=[]

for i in Product_URL:
    driver.get(i)
    try:
        read_more = driver.find_element_by_xpath('//button[@class="_2KpZ6l _1FH0tX"]')     # Button for expanding the specs
        read_more.click()
    except NoSuchElementException:
        print("Exception Occured. Moving to next page")
        
    try:
        name=driver.find_element_by_xpath("//span[@class='B_NuCI']")
        Name.append(name.text)
    except NoSuchElementException:
        Name.append("_")
    
    try:
        price=driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
        Price.append(price.text)
    except NoSuchElementException:
        Price.append("_")
        
    try:
        name = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')
        Model_name.append(name.text)
    except NoSuchElementException:
        Model_name.append('-')
    
    try:
        colour = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')
        Colour.append(colour.text)
    except NoSuchElementException:
        Colour.append('-')
    
    try:
        disp_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][2]/div')
        if disp_chk.text != "Display Features" : 
            raise NoSuchElementException
        disp_res = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][2]/table[1]/tbody/tr[2]/td[2]/ul/li')
        Display_Resolution.append(disp_res.text)
    except NoSuchElementException:
        Display_Resolution.append('-')
        
    try:
        pro_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[2]/td[1]')
        if pro_chk.text != "Processor Type" : 
            raise NoSuchElementException
        processor = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[2]/td[2]/ul/li')  
        Processor.append(processor.text)
    except NoSuchElementException:
        Processor.append('-')
        
        
    try:                      
        core_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[3]/td[1]')
        if core_chk.text != "Processor Core" :
            core_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[2]/td[1]')
            if core_chk.text != "Processor Core" : 
                raise NoSuchElementException
            else :
                cores = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[2]/td[2]/ul/li')
        else :
            cores = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[3]/td[2]/ul/li')
        Processor_Cores.append(cores.text)
    except NoSuchElementException:
        Processor_Cores.append('-')
        
    try:
        rom = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[1]/td[2]/ul/li')         # Extracting Storage(ROM) from xpath
        Storage_ROM.append(rom.text)
    except NoSuchElementException:
        Storage_ROM.append('-')
    
    try:
        ram = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[2]/td[2]/ul/li')                # Extracting RAM from xpath
        RAM.append(ram.text)
    except NoSuchElementException:
        RAM.append('-')
    
    try:                                                                                  
        pri_cam = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[2]/td[2]/ul/li') 
        Primary_Camera.append(pri_cam.text)
    except NoSuchElementException:
        Primary_Camera.append('-')
        
        
    try:                                                                                  
        cam_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[6]/td[1]')
        if cam_chk != "Secondary Camera" : 
            if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[1]').text == "Secondary Camera":
                sec_cam = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[2]/ul/li')
            else :
                raise NoSuchElementException
        else :
            sec_cam = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[6]/td[2]/ul/li')
            Secondary_Camera.append(sec_cam.text)
    except NoSuchElementException:
        Secondary_Camera.append('-')
        
    try:
        if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/div').text != "Battery & Power Features" : 
            if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/div').text == "Battery & Power Features" :
                bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[1]')
                if bat_chk.text != "Battery Capacity" : raise NoSuchElementException
                bat_cap = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[2]/ul/li')                
            elif driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/div').text == "Battery & Power Features" :     
                bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[1]')
                if bat_chk.text != "Battery Capacity" : raise NoSuchElementException
                bat_cap = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[2]/ul/li')
            else:
                raise NoSuchElementException
        else :
            bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[1]')
            if bat_chk.text != "Battery Capacity" : raise NoSuchElementException
            bat_cap = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[2]/ul/li')              
        Battery_Capacity.append(bat_cap.text)
    except NoSuchElementException:
        Battery_Capacity.append('-')
    
    try:
        if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/div').text != "Battery & Power Features" :
            if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/div').text == "Battery & Power Features" :
                bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr[2]/td[1]')
                if bat_chk.text != "Battery Type" : raise NoSuchElementException
                bat_typ = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr[2]/td[2]/ul/li')
            elif driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/div').text == "Battery & Power Features" :
                bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/table/tbody/tr[2]/td[1]')
                if bat_chk.text != "Battery Type" : raise NoSuchElementException
                bat_typ = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/table/tbody/tr[2]/td[2]/ul/li')
            else:
                raise NoSuchElementException
        else :
            bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr[2]/td[1]')
            if bat_chk.text != "Battery Type" : raise NoSuchElementException
            bat_typ = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr[2]/td[2]/ul/li')             # Extracting Battery Type from xpath
        Battery_Type.append(bat_typ.text)
    except NoSuchElementException:
        Battery_Type.append('-')

# %%
print(len(RAM),len(Name),len(Price),len(Colour),len(Model_name),len(Processor),len(Storage_ROM),len(Battery_Type),len(Processor_Cores),len(Primary_Camera),len(Battery_Capacity),len(Display_Resolution))
# Out:
# 24 24 24 24 24 24 24 24 24 24 24 24

# %%
Flip_Product=pd.DataFrame({})
Flip_Product['RAM']=RAM
Flip_Product['Name']=Name
Flip_Product['Price']=Price
Flip_Product['Colour']=Colour
Flip_Product['Model_name']=Model_name
Flip_Product['Processor']=Processor
Flip_Product['Storage_ROM']=Storage_ROM
Flip_Product['Battery_Type']=Battery_Type
Flip_Product['Processor_Cores']=Processor_Cores
Flip_Product['Primary_Camera']=Primary_Camera
Flip_Product['Battery_Capacity']=Battery_Capacity
Flip_Product['Display_Resolution']=Display_Resolution

# %%
Flip_Product
# Out:
#       RAM                                               Name    Price  \
# 0    6 GB   Google Pixel 4a (Just Black, 128 GB)  (6 GB RAM)  ₹31,999
# 1    4 GB  Google Pixel 3a (Clearly White, 64 GB)  (4 GB ...  ₹39,999
# 2    4 GB  REDMI 9 Power (Electric Green, 64 GB)  (4 GB RAM)  ₹10,499
# 3    4 GB    REDMI 9 Power (Blazing Blue, 64 GB)  (4 GB RAM)  ₹10,499
# 4    4 GB    REDMI 9 Power (Mighty Black, 64 GB)  (4 GB RAM)  ₹10,499
# 5    6 GB   REDMI 9 Power (Mighty Black, 128 GB)  (6 GB RAM)  ₹12,999
# 6    4 GB       REDMI 9 Power (Fiery Red, 64 GB)  (4 GB RAM)  ₹10,499
# 7    2 GB      Panasonic ELUGA I6 (Black, 16 GB)  (2 GB RAM)   ₹5,001
# 8    6 GB   REDMI 9 Power (Blazing Blue, 128 GB)  (6 GB RAM)  ₹12,999
# 9   32 MB                            LAVA Gem  (Blue Gold S)   ₹1,577
# 10   6 GB       SAMSUNG M31 (Ocean Blue, 128 GB)  (6 GB RAM)  ₹16,382
# 11   4 GB              Redmi 9 (Sky Blue, 64 GB)  (4 GB RAM)   ₹9,190
# 12   6 GB  REDMI 9 Power (Electric Green, 128 GB)  (6 GB ...  ₹12,999
# 13   4 GB   REDMI 9 Power (Mighty Black, 128 GB)  (4 GB RAM)  ₹11,999
# 14   4 GB  REDMI 9 Power (Electric Green, 128 GB)  (4 GB ...  ₹11,999
# 15   4 GB          Redmi 9 (Carbon Black, 64 GB)  (4 GB RAM)   ₹9,190
# 16   4 GB   REDMI 9 Power (Blazing Blue, 128 GB)  (4 GB RAM)  ₹11,999
# 17   6 GB        ViVO Y20G (Purist Blue, 128 GB)  (6 GB RAM)  ₹14,990
# 18   2 GB              Redmi 9A (SeaBlue, 32 GB)  (2 GB RAM)   ₹7,297
# 19   2 GB         Redmi 9A (Nature Green, 32 GB)  (2 GB RAM)   ₹7,213
# 20   8 GB  SAMSUNG Galaxy M31 (Ocean Blue, 128 GB)  (8 GB...  ₹17,965
# 21  32 MB                             Jmax J16  (Black Gold)     ₹699
# 22  32 MB                           KARBONN KX3  (Black,Red)     ₹890
# 23  32 MB  GFive i1 Combo of Two Mobiles  (Black : Black ...   ₹1,299
#
#                 Colour               Model_name                   Processor  \
# 0           Just Black                 Pixel 4a    Qualcomm Snapdragon 730G
# 1        Clearly White                 Pixel 3a     Qualcomm Snapdragon 670
# 2       Electric Green                  9 Power     Qualcomm Snapdragon 662
# 3         Blazing Blue                  9 Power     Qualcomm Snapdragon 662
# 4         Mighty Black                  9 Power     Qualcomm Snapdragon 662
# 5         Mighty Black                  9 Power   Qualcomm® Snapdragon™ 662
# 6            Fiery Red                  9 Power     Qualcomm Snapdragon 662
# 7                Black                 ELUGA I6                    MediaTek
# 8         Blazing Blue                  9 Power   Qualcomm® Snapdragon™ 662
# 9          Blue Gold S                      Gem                           -
# 10          Ocean Blue                      M31  Samsung Exynos 9 Octa 9611
# 11            Sky Blue                  Redmi 9          MediaTek Helio G35
# 12      Electric Green                  9 Power   Qualcomm® Snapdragon™ 662
# 13        Mighty Black                  9 Power     Qualcomm Snapdragon 662
# 14      Electric Green                  9 Power     Qualcomm Snapdragon 662
# 15        Carbon Black                  Redmi 9          MediaTek Helio G35
# 16        Blazing Blue                  9 Power     Qualcomm Snapdragon 662
# 17         Purist Blue                     Y20G                           -
# 18             SeaBlue                 Redmi 9A                           -
# 19        Nature Green                 Redmi 9A                           -
# 20          Ocean Blue               Galaxy M31  Samsung Exynos 9 Octa 9611
# 21          Black Gold                      J16                           -
# 22           Black,Red                      KX3                           -
# 23  Black : Black Blue  i1 Combo of Two Mobiles                           -
#
#    Storage_ROM     Battery_Type Processor_Cores          Primary_Camera  \
# 0       128 GB                -       Octa Core      12.2MP Rear Camera
# 1        64 GB                -       Octa Core      12.2MP Rear Camera
# 2        64 GB  lithium-polymer       Octa Core        48MP Rear Camera
# 3        64 GB  lithium-polymer       Octa Core        48MP Rear Camera
# 4        64 GB  lithium-polymer       Octa Core        48MP Rear Camera
# 5       128 GB  lithium-polymer       Octa Core        48MP Rear Camera
# 6        64 GB  lithium-polymer       Octa Core        48MP Rear Camera
# 7        16 GB       Li-Polymer       Quad Core         8MP Rear Camera
# 8       128 GB  lithium-polymer       Octa Core        48MP Rear Camera
# 9        32 MB           Li-Ion               -       1.3MP Rear Camera
# 10      128 GB      lithium-ion       Octa Core  64MP + 8MP + 5MP + 5MP
# 11       64 GB            Li-Po               -              13MP + 2MP
# 12      128 GB  lithium-polymer       Octa Core        48MP Rear Camera
# 13      128 GB  lithium-polymer       Octa Core        48MP Rear Camera
# 14      128 GB  lithium-polymer       Octa Core        48MP Rear Camera
# 15       64 GB            Li-Po       Octa Core              13MP + 2MP
# 16      128 GB  lithium-polymer       Octa Core        48MP Rear Camera
# 17      128 GB                -       Octa Core          Primary Camera
# 18       32 GB                -       Octa Core                       -
# 19       32 GB                -       Octa Core        13MP Rear Camera
# 20      128 GB      lithium-ion       Octa Core  64MP + 8MP + 5MP + 5MP
# 21       32 MB                -               -                       -
# 22       32 MB           Li-ion               -       0.3MP Rear Camera
# 23       32 MB                -               -       0.3MP Rear Camera
#
#    Battery_Capacity  Display_Resolution
# 0          3140 mAh  2340 x 1080 Pixels
# 1          3000 mAh  2220 x 1080 pixels
# 2          6000 mAh  2340 x 1080$$pixel
# 3          6000 mAh  2340 x 1080$$pixel
# 4          6000 mAh  2340 x 1080$$pixel
# 5          6000 mAh  2340 x 1080$$pixel
# 6          6000 mAh  2340 x 1080$$pixel
# 7          3000 mAh     960 x 480 pixel
# 8          6000 mAh  2340 x 1080$$pixel
# 9          1750 mAh    320 x 240$$pixel
# 10         6000 mAh  2340 x 1080$$pixel
# 11         5000 mAh   720 x 1600$$pixel
# 12         6000 mAh  2340 x 1080$$pixel
# 13         6000 mAh  2340 x 1080$$pixel
# 14         6000 mAh  2340 x 1080$$pixel
# 15         5000 mAh   720 x 1600$$pixel
# 16         6000 mAh  2340 x 1080$$pixel
# 17                -   1600 x 720$$pixel
# 18         5000 mAh   720 x 1600$$pixel
# 19         5000 mAh   720 x 1600$$pixel
# 20         6000 mAh  2340 x 1080$$pixel
# 21         2500 mAh    320 x 480$$pixel
# 22          800 mAh    128 x 160$$pixel
# 23         2500 mAh    320 x 480$$pixel
