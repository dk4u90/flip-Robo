# %% [markdown]
# Write a python program to scrap book name, author name, genre and book review of any 5 books from
# ‘www.bookpage.com’

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://bookpage.com/reviews')
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <title>Book Reviews | BookPage</title>
# <meta content="Book recommendations of the best new books by genre and more." name="description"/>
# <meta content="book reviews, books and literature, writing and writers" name="keywords"/>
# <link href="https://bookpage.com/reviews" rel="canonical"/>
# <meta content="BookPage.com" property="og:site_name"/>
# <meta content="Book Reviews" property="og:title"/>
# <meta content="Book recommendations of the best new books by genre and more." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://bookpage.com/reviews" property="og:url"/>
# <meta content="//www.bookpage.com/default_image.jpg" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@bookpage" name="twitter:site"/>
# <meta content="@bookpage" name="twitter:creator"/>
# ...

# %%
name=soup.find_all("h4",class_="italic")
name
# Out:
# [<h4 class="italic">
#  <a href="/reviews/26317-andrew-prahin-ship-bottle-childrens"> <span style="font-style:normal;">★ </span>Ship in a Bottle</a>
#  </h4>, <h4 class="italic">
#  <a href="/reviews/26327-emiko-jean-tokyo-ever-after-ya">Tokyo Ever After</a>
#  </h4>, <h4 class="italic">
#  <a href="/reviews/26289-natasha-pulley-kingdoms-fiction">The Kingdoms</a>
#  </h4>, <h4 class="italic">
#  <a href="/reviews/26275-craig-taylor-new-yorkers-audio">New Yorkers</a>
#  </h4>, <h4 class="italic">
#  <a href="/reviews/26297-ashley-herring-blake-hazel-bly-deep-blue-sea-childrens"> <span style="font-style:normal;">★ </span>Hazel Bly and the Deep Blue Sea</a>
#  </h4>, <h4 class="italic">
#  <a href="/reviews/26277-dawnie-walton-final-revival-opal-nev-audio"> <span style="font-style:normal;">★ </span>The Final Revival of Opal &amp; Nev</a>
#  </h4>, <h4 class="italic">
#  <a href="/reviews/26345-cynthia-leitich-smith-sisters-neversea-childrens">Sisters of the Neversea</a>
# ...

# %%
book_name=[]
for i in name:
  book_name.append(i.text.replace('\n',''))
book_name[:100]
# Out:
# [' ★ Ship in a Bottle',
#  'Tokyo Ever After',
#  'The Kingdoms',
#  'New Yorkers',
#  ' ★ Hazel Bly and the Deep Blue Sea',
#  ' ★ The Final Revival of Opal & Nev',
#  'Sisters of the Neversea',
#  ' ★ American Republics',
#  ' ★ Light Perpetual',
#  'Big Time']

# %%
auther=soup.find_all("p",class_="sans bold")
auther
# Out:
# [<p class="sans bold">
#  Andrew Prahin
#  </p>, <p class="sans bold">
#  Emiko Jean
#  </p>, <p class="sans bold">
#  Natasha Pulley
#  </p>, <p class="sans bold">
#  Craig Taylor, Cast
#  </p>, <p class="sans bold">
#  Ashley Herring Blake
#  </p>, <p class="sans bold">
#  Dawnie Walton, Cast
#  </p>, <p class="sans bold">
#  Cynthia Leitich Smith
#  </p>, <p class="sans bold">
#  Alan Taylor
#  </p>, <p class="sans bold">
#  Francis Spufford
#  </p>, <p class="sans bold">
#  Jen Spyra, Cast
#  </p>]

# %%
book_auther=[]
for i in auther:
  book_auther.append(i.text.replace('\n',''))
book_auther[:100]
# Out:
# ['Andrew Prahin',
#  'Emiko Jean',
#  'Natasha Pulley',
#  'Craig Taylor, Cast',
#  'Ashley Herring Blake',
#  'Dawnie Walton, Cast',
#  'Cynthia Leitich Smith',
#  'Alan Taylor',
#  'Francis Spufford',
#  'Jen Spyra, Cast']

# %%
review=soup.find_all("p",class_="excerpt")
review
# Out:
# [<p class="excerpt">
#  </p>, <p class="excerpt">
#  </p>, <p class="excerpt">
#  Natasha Pulley balances the topsy-turvy nature of time travel by grounding her story in naval history and a gradually unfolding queer love story.
#  </p>, <p class="excerpt">
#  “This city barged into conversations,” Craig Taylor says about <strong>New Yorkers</strong>. With that kind of attitude, you’ll have no choice but to listen in.
#  </p>, <p class="excerpt">
#  Nothing has been the same for Hazel or her family since Mum drowned in a kayaking accident. Hazel sees danger everywhere and never leaves the house without her blue “Safety Pack.” Her little sister, Peach, knows and feels much more than she lets on. And Hazel’s surviving parent,...
#  </p>, <p class="excerpt">
#  After listening to this incredible audiobook, if you didn’t know better, you’d rush out to scour your local music store for Opal &amp; Nev’s long-lost albums.
#  </p>, <p class="excerpt">
#  </p>, <p class="excerpt">
# ...

# %%
book_review=[]
for i in review:
  book_review.append(i.text.replace('\n',''))
book_review[:100]
# Out:
# ['',
#  '',
#  'Natasha Pulley balances the topsy-turvy nature of time travel by grounding her story in naval history and a gradually unfolding queer love story.',
#  '“This city barged into conversations,” Craig Taylor says about New Yorkers. With that kind of attitude, you’ll have no choice but to listen in.',
#  'Nothing has been the same for Hazel or her family since Mum drowned in a kayaking accident. Hazel sees danger everywhere and never leaves the house without her blue “Safety Pack.” Her little sister, Peach, knows and feels much more than she lets on. And Hazel’s surviving parent,...',
#  'After listening to this incredible audiobook, if you didn’t know better, you’d rush out to scour your local music store for Opal & Nev’s long-lost albums.',
#  '',
#  'Pulitzer Prize winner Alan Taylor’s latest American history is sweeping, beautifully written, prodigiously researched and myth-busting.',
# ...

# %%
genrs=soup.find_all("p",class_="genre-links hidden-phone")
genrs
# Out:
# [<p class="genre-links hidden-phone">
#  <a href="/search?book_genre=children_s">Children's</a>
#   /
#  <a href="/search?book_genre=children_s_picture_book">Children's Picture Book</a>
#  </p>, <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=ya">YA</a>
#   /
#  <a href="/search?book_genre=ya_fiction">YA Fiction</a>
#  </p>, <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=fiction">Fiction</a>
#   /
#  <a href="/search?book_genre=speculative_fiction">Speculative Fiction</a>
#  </p>, <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=audio">Audio</a>
#   /
#  <a href="/search?book_genre=nonfiction">Nonfiction</a>
#   /
#  <a href="/search?book_genre=culture">Culture</a>
#  </p>, <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=children_s">Children's</a>
#   /
#  <a href="/search?book_genre=middle_grade">Middle Grade</a>
#  </p>, <p class="genre-links hidden-phone">
# ...

# %%
book_genrs=[]
for i in genrs:
  book_genrs.append(i.text.replace('\n',''))
book_genrs[:100]
# Out:
# ["Children's / Children's Picture Book",
#  'YA / YA Fiction',
#  'Fiction / Speculative Fiction',
#  'Audio / Nonfiction / Culture',
#  "Children's / Middle Grade",
#  'Audio / Fiction / Literary Fiction',
#  "Children's / Middle Grade",
#  'Nonfiction / History / American History',
#  'Fiction / Literary Fiction',
#  'Audio / Fiction / Short Stories']

# %%
import pandas as pd
Book=pd.DataFrame({})
Book['book_name']=book_name
Book['book_auther']=book_auther
Book['book_genrs']=book_genrs
Book['book_review']=book_review

# %%
Book[:5]
# Out:
#                             book_name  ...                                        book_review
# 0                  ★ Ship in a Bottle  ...
# 1                    Tokyo Ever After  ...
# 2                        The Kingdoms  ...  Natasha Pulley balances the topsy-turvy nature...
# 3                         New Yorkers  ...  “This city barged into conversations,” Craig T...
# 4   ★ Hazel Bly and the Deep Blue Sea  ...  Nothing has been the same for Hazel or her fam...
#
# [5 rows x 4 columns]
